# %%
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 14.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.5

# %%
import fitz  # PyMuPDF
import os
import json

def extract_text_from_pdf(pdf_path):
    with fitz.open(pdf_path) as doc:
        text = ""
        for page in doc:
            text += page.get_text()
    return text

# Directory containing PDFs
pdf_dir = "./Raw"
output_json = "extracted_texts.json"

# Dictionary to hold results
pdf_texts = {}

# Loop through all PDF files in the directory
for filename in os.listdir(pdf_dir):
    if filename.lower().endswith(".pdf"):
        file_path = os.path.join(pdf_dir, filename)
        print(f"Extracting: {filename}")
        pdf_texts[filename] = extract_text_from_pdf(file_path)

# Save to JSON file
with open(output_json, "w", encoding="utf-8") as f:
    json.dump(pdf_texts, f, ensure_ascii=False, indent=2)

print(f"Extraction complete. Results saved to {output_json}")
# Out:
# Extracting: s11739-020-02355-7.pdf
# Extracting: association_between_smoking_and_covid_19_severity_.39.pdf
# Extracting: bogdański-et-al-2020-smoking-vaping-and-tobacco-industry-during-covid-19-pandemic-twitter-data-analysis.pdf
# Extracting: smoking.pdf
# Extracting: fphys-12-603850.pdf
# Extracting: TID-19-09.pdf
# Extracting: PJMS-36-S104.pdf
# Extracting: 1-s2.0-S1054139X20303992-main.pdf
# Extracting: s10900-020-00880-2.pdf
# Extracting: main (2).pdf
# Extracting: 1-s2.0-S0376871621006396-main.pdf
# Extracting: jcvtr-12-136.pdf
# Extracting: 30-Articolo-97-2-10-20210907.pdf
# Extracting: TID-18-20.pdf
# Extracting: s12889-021-11579-x.pdf
# Extracting: TID-18-63.pdf
# Extracting: file.pdf
# Extracting: hpr-8-1-9124.pdf
# Extracting: Journal of Medical Virology - 2020 - Reddy - The effect of smoking on COVID‐19 severity  A systematic review and.pdf
# Extracting: beliefs_about_the_effects_of_smoking_on_corona.2.pdf
# Extracting: ntab112.pdf
# Extracting: ERJ-01290-2020.pdf
# Extracting: Addiction - 2020 - Tattan‐Birch - COVID‐19  smoking  vaping and quitting  a representative population survey in England.pdf
# Extracting: IJPH-50-431.pdf
# Extracting: journal.pone.0238552.pdf
# Extracting: TID-21-77.pdf
# Extracting: main (3).pdf
# Extracting: haddad-et-al-2021-smoking-and-covid-19-a-scoping-review.pdf
# Extracting: ntaa082.pdf
# Extracting: eakin-neptune-2021-smoking-and-covid-19-the-real-deal.pdf
# Extracting: journal.pone.0255692.pdf
# Extracting: al-tammemi-et-al-2021-beliefs-toward-smoking-and-covid-19-and-the-pandemic-impact-on-smoking-behavior-and-quit.pdf
# Extracting: main.pdf
# Extracting: ntab004.pdf
# Extracting: journal.pone.0280337.pdf
# Extracting: Association Between Smoking and COVID-19 Severity  Evidence from Bangladesh.pdf
# Extracting: jpm-14-00097-v2.pdf
# Extracting: Smoking_vaping_and_hospitalization_for_C.pdf
# Extracting: ntaa075.pdf
# Extracting: main (4).pdf
# Extracting: rodgers-et-al-2021-smoking-and-covid-19-a-literature-review-of-cohort-studies-in-non-chinese-population-settings.pdf
# Extracting: TID-18-89.pdf
# Extracting: s11606-021-06913-3.pdf
# Extracting: qt22m8z3sq.pdf
# Extracting: ecr-15-e16.pdf
# Extracting: ERJ-01340-2020.pdf
# Extracting: TPC-6-39.pdf
# Extracting: main (1).pdf
# Extracting: ADD-116-982.pdf
# Extracting: s12954-020-00437-5.pdf
# Extracting: dyac028.pdf
# Extracting: 1612431103-1612431097-20210204-18204-d4v402.pdf
# Extracting: 1-s2.0-S0953620520302314-main.pdf
# Extracting: fpsyt-13-941575.pdf
# Extracting: cai-et-al-2020-reply-to-polverino-cigarette-smoking-and-covid-19-a-complex-interaction.pdf
# Extracting: E462.full.pdf
# Extracting: e000716.full.pdf
# Extracting: fphys-12-634842.pdf
# Extracting: effects-of-smoking-on-covid-19-management-and-mortality-an-umbrella-review.pdf
# Extracting: e052777.full.pdf
# Extracting: farsalinos-et-al-2020-current-smoking-former-smoking-and-adverse-outcome-among-hospitalized-covid-19-patients-a.pdf
# Extracting: ERJ-01759-2020.pdf
# Extracting: ntaa121.pdf
# Extracting: TID-20-18.pdf
# Extracting: Journal of Internal Medicine - 2020 - Li - Tobacco smoking confers risk for severe COVID‐19 unexplainable by pulmonary.pdf
# Extracting: 1-s2.0-S0749379721004992-main.pdf
# Extracting: TID-18-58.pdf
# Extracting: 0042-84502005461I.pdf
# Extracting: Smoking and COVID-19 Infection and Related Mortality  A Prospective Cohort Analysis of UK Biobank Data.pdf
# Extracting: TID-18-37.pdf
# Extracting: PIIS2213260020302393.pdf
# Extracting: 714.full.pdf
# Extracting: JMV-92-2304.pdf
# Extracting: s41533-021-00238-8.pdf
# Extracting: TID-21-11.pdf
# Extracting: bmjnph-2021-000269.pdf
# Extracting: 1-s2.0-S0955395922000275-main.pdf
# Extracting: ntaa059.pdf
# Extracting: ACTA-91-106.pdf
# Extracting: s10900-022-01085-5.pdf
# Extracting: s11739-020-02361-9.pdf
# Extracting: gaffney-et-al-2022-smoking-prevalence-during-the-covid-19-pandemic-in-the-united-states.pdf
# Extracting: NDIGOC092507_2020_004.pdf
# Extracting: s41598-021-98749-4.pdf
# Extracting: 2020.06.01.20118877v2.full.pdf
# Extracting: s42003-021-02685-y.pdf
# Extracting: VGJCUN.pdf
# Extraction complete. Results saved to extracted_texts.json
